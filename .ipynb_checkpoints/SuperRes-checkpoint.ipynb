# %% [markdown]
# # Super Resolution and Fast Style Transfer

# %% [markdown]
# By https://arxiv.org/pdf/1603.08155.pdf and supplemential materials https://cs.stanford.edu/people/jcjohns/papers/fast-style/fast-style-supp.pdf

# %% [markdown]
# ## Imports and data loading

# %%
import numpy as np
import bcolz
import importlib
import tensorflow as tf

import keras
from keras.layers import Convolution2D, Deconvolution2D, MaxPooling2D
from keras.layers import AveragePooling2D, Input, BatchNormalization, Activation
from keras.layers import merge, Lambda
from keras.optimizers import Adam
from keras.applications import VGG16
from keras.models import Sequential, Model
from keras import backend as K
from keras.metrics import mse
from keras_tqdm import TQDMNotebookCallback

from vgg16_avg import VGG16_Avg

# %matplotlib inline
import matplotlib.pyplot as plt
import utils2
importlib.reload(utils2)
from utils2 import save_array, load_array, plot, plot_multi, limit_mem
# Out:
# Using TensorFlow backend.
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
limit_mem()

# %% [markdown]
# Now load the data: small images (72x72) and their ground-truth(288x288)

# %%
small_imgs = load_array('../SuperResData/trn_resized_72.bc')
large_imgs = load_array('../SuperResData/trn_resized_288.bc')

# %%
plot_multi([small_imgs[11].astype('uint8'), large_imgs[11].astype('uint8')],
           figsize=(15, 15))

# %% [markdown]
# ## Upscale net

# %% [markdown]
# The Upscale network that will scale the small image into a big one.

# %%
def conv_block(inp, filters, size, stride=1, activation=True):
    ''' Define a convolutional block for the upscale network.
    '''
    x = Convolution2D(nb_filter=filters, nb_row=size[0], nb_col=size[1],
                      border_mode='same', name='')(inp)
    x = BatchNormalization()(x)
    if activation:
        return Activation(activation='relu')(x)
    else:
        return x

# %%
def res_block(inp, filters):
    x = conv_block(inp, filters=64, size=(3, 3))
    x = conv_block(x, filters=64, size=(3, 3), activation=False)
    x = merge([x, inp], mode='sum')
    return x

# %%
def deconv_block(inp, filters, size, output_shape, stride=2):
    x = Deconvolution2D(nb_filter=filters,
                        nb_row=size[0], nb_col=size[1],
                        output_shape=output_shape,
                        subsample=(stride, stride), border_mode='same')(inp)
    x = BatchNormalization()(x)
    return Activation('relu')(x)

# %%
input_shape = small_imgs.shape[1:]
input_small = Input(shape=input_shape)
x = conv_block(input_small, filters=64, size=(9, 9))
x = res_block(x, 64)
x = res_block(x, 64)
x = res_block(x, 64)
x = res_block(x, 64)
x = deconv_block(x, 64, size=(3, 3), output_shape=(None, 144, 144, 64))
x = deconv_block(x, 64, size=(3, 3), output_shape=(None, 288, 288, 64))
x = Convolution2D(nb_filter=3, nb_row=9, nb_col=9,
                  activation='tanh', border_mode='same')(x)
enlarge_output = Lambda(lambda x: (x + 1) * 127.5)(x)

# %%
enlarge_net = Model(input_small, enlarge_output)
enlarge_net.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_10 (InputLayer)            (None, 72, 72, 3)     0
# ____________________________________________________________________________________________________
# convolution2d_11 (Convolution2D) (None, 72, 72, 64)    15616       input_10[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_12 (BatchNorm (None, 72, 72, 64)    256         convolution2d_11[0][0]
# ____________________________________________________________________________________________________
# activation_8 (Activation)        (None, 72, 72, 64)    0           batchnormalization_12[0][0]
# ____________________________________________________________________________________________________
# convolution2d_12 (Convolution2D) (None, 72, 72, 64)    36928       activation_8[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_13 (BatchNorm (None, 72, 72, 64)    256         convolution2d_12[0][0]
# ____________________________________________________________________________________________________
# activation_9 (Activation)        (None, 72, 72, 64)    0           batchnormalization_13[0][0]
# ____________________________________________________________________________________________________
# convolution2d_13 (Convolution2D) (None, 72, 72, 64)    36928       activation_9[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_14 (BatchNorm (None, 72, 72, 64)    256         convolution2d_13[0][0]
# ____________________________________________________________________________________________________
# merge_5 (Merge)                  (None, 72, 72, 64)    0           batchnormalization_14[0][0]
#                                                                    activation_8[0][0]
# ____________________________________________________________________________________________________
# convolution2d_14 (Convolution2D) (None, 72, 72, 64)    36928       merge_5[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_15 (BatchNorm (None, 72, 72, 64)    256         convolution2d_14[0][0]
# ____________________________________________________________________________________________________
# activation_10 (Activation)       (None, 72, 72, 64)    0           batchnormalization_15[0][0]
# ____________________________________________________________________________________________________
# convolution2d_15 (Convolution2D) (None, 72, 72, 64)    36928       activation_10[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_16 (BatchNorm (None, 72, 72, 64)    256         convolution2d_15[0][0]
# ____________________________________________________________________________________________________
# merge_6 (Merge)                  (None, 72, 72, 64)    0           batchnormalization_16[0][0]
#                                                                    merge_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_16 (Convolution2D) (None, 72, 72, 64)    36928       merge_6[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_17 (BatchNorm (None, 72, 72, 64)    256         convolution2d_16[0][0]
# ____________________________________________________________________________________________________
# activation_11 (Activation)       (None, 72, 72, 64)    0           batchnormalization_17[0][0]
# ____________________________________________________________________________________________________
# convolution2d_17 (Convolution2D) (None, 72, 72, 64)    36928       activation_11[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_18 (BatchNorm (None, 72, 72, 64)    256         convolution2d_17[0][0]
# ____________________________________________________________________________________________________
# merge_7 (Merge)                  (None, 72, 72, 64)    0           batchnormalization_18[0][0]
#                                                                    merge_6[0][0]
# ____________________________________________________________________________________________________
# convolution2d_18 (Convolution2D) (None, 72, 72, 64)    36928       merge_7[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_19 (BatchNorm (None, 72, 72, 64)    256         convolution2d_18[0][0]
# ____________________________________________________________________________________________________
# activation_12 (Activation)       (None, 72, 72, 64)    0           batchnormalization_19[0][0]
# ____________________________________________________________________________________________________
# convolution2d_19 (Convolution2D) (None, 72, 72, 64)    36928       activation_12[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_20 (BatchNorm (None, 72, 72, 64)    256         convolution2d_19[0][0]
# ____________________________________________________________________________________________________
# merge_8 (Merge)                  (None, 72, 72, 64)    0           batchnormalization_20[0][0]
#                                                                    merge_7[0][0]
# ____________________________________________________________________________________________________
# deconvolution2d_3 (Deconvolution (None, 144, 144, 64)  36928       merge_8[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_21 (BatchNorm (None, 144, 144, 64)  256         deconvolution2d_3[0][0]
# ____________________________________________________________________________________________________
# activation_13 (Activation)       (None, 144, 144, 64)  0           batchnormalization_21[0][0]
# ____________________________________________________________________________________________________
# deconvolution2d_4 (Deconvolution (None, 288, 288, 64)  36928       activation_13[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_22 (BatchNorm (None, 288, 288, 64)  256         deconvolution2d_4[0][0]
# ____________________________________________________________________________________________________
# activation_14 (Activation)       (None, 288, 288, 64)  0           batchnormalization_22[0][0]
# ____________________________________________________________________________________________________
# convolution2d_20 (Convolution2D) (None, 288, 288, 3)   15555       activation_14[0][0]
# ____________________________________________________________________________________________________
# lambda_8 (Lambda)                (None, 288, 288, 3)   0           convolution2d_20[0][0]
# ====================================================================================================
# Total params: 403,267
# Trainable params: 401,859
# Non-trainable params: 1,408
# ____________________________________________________________________________________________________

# %% [markdown]
# ## VGG for content features

# %%
channel_means = np.array([123.68, 116.779, 103.939], dtype=np.float32)
preprocess = Lambda(lambda x: (x - channel_means)[:, :, :, ::-1])

# %%
# vgg_input = Input(shape=large_imgs.shape[1:])
vgg = VGG16_Avg(include_top=False)
for layer in vgg.layers:
    layer.trainable = False
vgg.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_11 (InputLayer)            (None, None, None, 3) 0
# ____________________________________________________________________________________________________
# block1_conv1 (Convolution2D)     (None, None, None, 64 1792        input_11[0][0]
# ____________________________________________________________________________________________________
# block1_conv2 (Convolution2D)     (None, None, None, 64 36928       block1_conv1[0][0]
# ____________________________________________________________________________________________________
# block1_pool (AveragePooling2D)   (None, None, None, 64 0           block1_conv2[0][0]
# ____________________________________________________________________________________________________
# block2_conv1 (Convolution2D)     (None, None, None, 12 73856       block1_pool[0][0]
# ____________________________________________________________________________________________________
# block2_conv2 (Convolution2D)     (None, None, None, 12 147584      block2_conv1[0][0]
# ____________________________________________________________________________________________________
# block2_pool (AveragePooling2D)   (None, None, None, 12 0           block2_conv2[0][0]
# ____________________________________________________________________________________________________
# block3_conv1 (Convolution2D)     (None, None, None, 25 295168      block2_pool[0][0]
# ____________________________________________________________________________________________________
# block3_conv2 (Convolution2D)     (None, None, None, 25 590080      block3_conv1[0][0]
# ____________________________________________________________________________________________________
# block3_conv3 (Convolution2D)     (None, None, None, 25 590080      block3_conv2[0][0]
# ____________________________________________________________________________________________________
# block3_pool (AveragePooling2D)   (None, None, None, 25 0           block3_conv3[0][0]
# ____________________________________________________________________________________________________
# block4_conv1 (Convolution2D)     (None, None, None, 51 1180160     block3_pool[0][0]
# ____________________________________________________________________________________________________
# block4_conv2 (Convolution2D)     (None, None, None, 51 2359808     block4_conv1[0][0]
# ____________________________________________________________________________________________________
# block4_conv3 (Convolution2D)     (None, None, None, 51 2359808     block4_conv2[0][0]
# ____________________________________________________________________________________________________
# block4_pool (AveragePooling2D)   (None, None, None, 51 0           block4_conv3[0][0]
# ____________________________________________________________________________________________________
# block5_conv1 (Convolution2D)     (None, None, None, 51 2359808     block4_pool[0][0]
# ____________________________________________________________________________________________________
# block5_conv2 (Convolution2D)     (None, None, None, 51 2359808     block5_conv1[0][0]
# ____________________________________________________________________________________________________
# block5_conv3 (Convolution2D)     (None, None, None, 51 2359808     block5_conv2[0][0]
# ____________________________________________________________________________________________________
# block5_pool (AveragePooling2D)   (None, None, None, 51 0           block5_conv3[0][0]
# ====================================================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# ____________________________________________________________________________________________________

# %%
vgg_content_features = Model(
    vgg.input, vgg.get_layer(name='block2_conv2').output)

# %%
# Test the VGG net
sample_image = small_imgs[0][np.newaxis]
computed_features = K.get_value(vgg_content_features(sample_image))

# %% [markdown]
# ## Super Res net

# %% [markdown]
# Upscale the small image, and minimize the loss between the upscaled and the ground truth images.

# %%
truth_input = Input(shape=large_imgs.shape[1:])
truth_features = vgg_content_features(preprocess(truth_input))

# %%
upscaled_features = vgg_content_features(preprocess(enlarge_net.output))

# %%
truth_features, upscaled_features
# Out:
# (<tf.Tensor 'Relu_93:0' shape=(?, 144, 144, 128) dtype=float32>,
#  <tf.Tensor 'Relu_97:0' shape=(?, ?, ?, 128) dtype=float32>)

# %%
def loss_func(x):
    rmse = K.sqrt(K.mean(K.square(x[0] - x[1]), axis=(1, 2)))
    return rmse


loss = Lambda(loss_func)([truth_features, upscaled_features])
loss
# Out:
# Tensor("Sqrt_49:0", shape=(?, 128), dtype=float32)
# <tf.Tensor 'Sqrt_49:0' shape=(?, 128) dtype=float32>

# %%
super_res = Model((input_small, truth_input), loss)
lr = 1e-3
super_res.compile(optimizer=Adam(lr=lr), loss='mse')

# %%
params = {'verbose': 0, 'callbacks': [TQDMNotebookCallback(leave_inner=True)]}
fake_targets = np.zeros((large_imgs.shape[0],) + (128,))
super_res.fit([small_imgs, large_imgs], fake_targets,
              batch_size=16, nb_epoch=1, **params)

# %%
K.set_value(super_res.optimizer.lr, 1e-4)
super_res.fit([small_imgs, large_imgs], fake_targets,
              batch_size=16, nb_epoch=2, **params)

# %%
K.set_value(super_res.optimizer.lr, 1e-5)
super_res.fit([small_imgs, large_imgs], fake_targets,
              batch_size=16, nb_epoch=2, **params)

# %%
final_model = Model(input_small, enlarge_output)
final_model.save('enlarge_model.hdf5')

# %%
img_index = 11
test_img = small_imgs[img_index:img_index + 1]
target_img = large_imgs[img_index].astype('uint8')
plot_multi(test_img.astype('uint8'), figsize=(15, 15))

# %%
enlarged_img = final_model.predict(test_img)
enlarged_img = np.squeeze(enlarged_img.astype('uint8'))
enlarged_img.shape
# Out:
# (288, 288, 3)

# %%
small_img = np.squeeze(test_img.astype('uint8'))
plot_multi([small_img, enlarged_img, target_img], figsize=(22, 22))
